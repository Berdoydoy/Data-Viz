# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#        County  Total Cases  Recovered Cases  Deceased Among Cases  \
# 0      Aurora          860              840                    17
# 1      Beadle         5159             5089                    63
# 2     Bennett          858              842                    15
# 3   Bon Homme         2404             2362                    41
# 4   Brookings         8909             8838                    59
# ..        ...          ...              ...                   ...
# 60     Turner         2116             2049                    63
# 61      Union         4206             4152                    52
# 62   Walworth         1440             1410                    26
# 63    Yankton         6512             6437                    60
# 64    Ziebach          695              681                    11
#
#    Community Spread % PCR Test Positivity Rate (Weekly)  Variant Cases  \
# 0      Substantial*                               0.00%              0
# ...

# %%
sns.barplot(data=df,x="Community Spread",y='Total Cases')
# Out:
# <AxesSubplot:xlabel='Community Spread', ylabel='Total Cases'>

# %%
sms.histplot?
# Out:
# Object `sms.histplot` not found.
